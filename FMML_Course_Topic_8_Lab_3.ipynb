# %% [markdown]
# <a href="https://colab.research.google.com/github/saicharanuddisa/FMML_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 13:15:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   261MB/s    in 0.3s
#
# 2024-04-08 13:15:02 (261 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18483   1012.3410v1  A new distance function dist(A,B) for fuzzy se...    cs
# 16130  1610.00031v1  We present an analysis of the performance of m...    cs
# 40903   1003.1499v1  This paper introduces an evaluation methodolog...    cs
# 30207  1711.09017v1  Learning-based methods are believed to work we...    cs
# 21976   1211.3589v3  We study inference and learning based on a spa...  stat
# ...             ...                                                ...   ...
# 6241   1610.02757v1  Our team won the second prize of the Safe Agin...  stat
# 15625  1511.05389v4  Many Proper Names (PNs) are Out-Of-Vocabulary ...    cs
# 3701   1606.00787v2  While Bayesian methods are praised for their a...  stat
# 40578   0812.3147v1  We investigate the performance of a simple sig...    cs
# 21718   1101.0317v1  In the applications related to airborne radars...  stat
#
#                                                    title  year  \
# 18483  Descriptive-complexity based distance for fuzz...  2010
# 16130  Discriminating Similar Languages: Evaluations ...  2016
# 40903  Evaluation of E-Learners Behaviour using Diffe...  2010
# 30207  MPIIGaze: Real-World Dataset and Deep Appearan...  2017
# 21976  A Truncated EM Approach for Spike-and-Slab Spa...  2012
# ...                                                  ...   ...
# 6241   Dataiku's Solution to SPHERE's Activity Recogn...  2016
# 15625  Learning to retrieve out-of-vocabulary words i...  2015
# 3701                       Post-Inference Prior Swapping  2016
# 40578  Comparison of Binary Classification Based on S...  2008
# 21718  Generation of SAR Image for Real-life Objects ...  2011
#
#                                                 keywords
# 18483  [introduced, descriptive, complexity, symmetri...
# 16130  [performance, classifiers, discriminating, lan...
# 40903  [introduces, evaluation, methodologies, behavi...
# 30207  [unconstrained, estimation, estimation, monocu...
# 21976  [inference, independent, distribution, applica...
# ...                                                  ...
# 6241   [challenge, organized, conjunction, competitio...
# 15625  [vocabulary, recognition, diachronic, retrieve...
# 3701   [incorporate, knowledge, convenient, computati...
# 40578  [investigate, performance, comparison, experim...
# 21718  [applications, simulation, important, unavaila...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18483    [introduced, descriptive, complexity, symmetri...
# 16130    [performance, classifiers, discriminating, lan...
# 40903    [introduces, evaluation, methodologies, behavi...
# 30207    [unconstrained, estimation, estimation, monocu...
# 21976    [inference, independent, distribution, applica...
#                                ...
# 22085    [dimensional, structured, unobserved, affectin...
# 33306    [randomized, heuristics, classical, evolutiona...
# 4037     [construct, extension, diffusion, modalities, ...
# 11755    [heuristic, optimization, normalized, directio...
# 39976    [conventional, authentication, technologies, a...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8728 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="075f9c6c-973d-4cdd-9803-e80998a6ee68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("075f9c6c-973d-4cdd-9803-e80998a6ee68")) {                    Plotly.newPlot(                        "075f9c6c-973d-4cdd-9803-e80998a6ee68",                        [{"x":["introduced","additional","symmetric","properties","descriptive","information","clustering","complexity","difference","mathematical","difficult","explorations","discriminating","investigated","investigate","understand","challenging","experiments","performance","evaluations","sentences","classifiers","varieties","annotation","languages","combination","identified","evaluation","comparison","techniques","kernelized","represent","percentage","selection","categories","different","predicting","introduces","behaviour","preparation","comparative","presented","methodologies","description","continuous","facilitate","contributions","appearance","evaluated","annotated","unconstrained","extensive","conditions","resolution","variation","assumptions","regarding","experience","laboratory","illumination","collected","positions","challenges","environment","informative","monocular","corresponding","including","addressing","estimation","limitations","realistic","increasing","contribution","posteriors","parameters","approaches","posterior","distributions","furthermore","benchmark","denoising","saturates","variational","independent","independently","contributes","separation","benchmarks","dimensions","applications","independence","truncated","inference","distribution","application","computational","alternating","simultaneously","regularization","minimization","relationship","multitask","experimental","formulated","formulation","efficiently","significantly","comparable","formulations","algorithm","framework","outperform","incorporate","automatically","leveraging","knowledge","reinforced","developed","numerical","annealing","augmented","stochastic","evolutionary","optimization","competitive","respectively","differential","polynomial","engineering","simplified","efficiency","practical","stability","algorithms","evolution","robustness","performed","simulated","submodular","establish","functions","penalized","relaxation","combinatorial","tightness","situation","penalties","regularized","represents","parameter","relaxations","representations","structured","characterizes","introduce","procedure","intuitive","completing","structural","satisfies","constraint","incoherence","advantages","incoherent","uniformly","recovered","proportional","according","completion","currently","probability","important","restrictive","necessary","characterize","interpretability","comparing","procedures","association","portraying","understanding","applicability","interpretable","identifying","databases","constructed","dictionaries","integrate","etymological","principles","continuum","comprehensive","systematic","interested","possibilities","seamlessly","contribute","representation","designing"],"y":[131,126,29,217,11,679,154,222,56,51,143,2,3,49,158,64,263,640,884,49,76,121,3,66,106,128,48,300,140,378,5,116,17,154,67,786,76,63,39,6,31,187,17,74,102,49,46,71,153,82,24,185,149,112,62,57,35,45,13,39,86,25,106,142,46,19,142,262,33,201,59,58,103,70,8,254,427,42,101,169,230,50,1,60,109,52,11,28,95,40,432,37,9,215,235,263,309,33,113,88,67,82,10,372,27,85,163,264,97,19,856,539,94,58,165,42,355,3,203,91,13,30,128,66,339,110,83,30,69,53,22,185,146,33,624,65,113,131,59,14,46,193,3,28,43,6,37,6,38,53,118,8,228,111,9,340,117,39,5,73,10,85,3,88,4,17,12,13,107,38,52,169,343,4,68,51,21,78,40,34,2,167,33,37,78,64,70,16,44,2,47,4,65,40,36,11,12,25,365,43],"type":"bar"},{"x":["introduced","additional","symmetric","properties","descriptive" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Human</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Understandable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <span style='background-color:rgba(0, 255, 0, 0.6273291925465838);'>Extraction</span> <span style=''>for</span> <span style=''>Black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>Models</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>Factorization</span> <br/><br/><span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3977272727272728);'>artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7586206896551724);'>intelligent</span> <span style=''>services</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>such</span> <span style=''>as</span> <span style=''>defect</span> <span style='background-color:rgba(0, 255, 0, 0.5854214123006832);'>detection</span> <span style=''>system</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.5692307692307692);'>diagnosis</span> <span style=''>system</span> <span style=''>for</span> <span style=''>customer</span> <span style=''>services</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <span style=''>the</span> <span style=''>core</span> <span style=''>in</span> <span style=''>these</span> <span style=''>services</span> <span style=''>is</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>in</span> <span style=''>which</span> <span style=''>human</span> <span style=''>cannot</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understand</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>logic</span> <span style=''>even</span> <span style=''>though</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>inspection</span> <span style=''>of</span> <span style=''>the</span> <span style=''>logic</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>before</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>launching</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>commercial</span> <span style=''>service</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>analytic</span> <span style=''>method</span> <span style=''>of</span> <span style=''>a</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>models</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Practical</span> <span style=''>Hash</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <br/><br/><span style=''>Hashing</span> <span style=''>is</span> <span style=''>a</span> <span style=''>basic</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>several</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>the</span> <span style=''>perfomance</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>often</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>under</span> <span style=''>the</span> <span style=''>abstract</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>a</span> <span style=''>truly</span> <span style=''>random</span> <span style=''>unit</span> <span style=''>cost</span> <span style=''>hash</span> <span style=''>function</span> <span style=''>is</span> <span style=''>used</span> <span style=''>without</span> <span style=''>concern</span> <span style=''>for</span> <span style=''>which</span> <span style=''>concrete</span> <span style=''>hash</span> <span style=''>function</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>The</span> <span style=''>concrete</span> <span style=''>hash</span> <span style=''>function</span> <span style=''>may</span> <span style=''>work</span> <span style=''>fine</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>random</span> <span style=''>input</span> <span style=''>The</span> <span style=''>question</span> <span style=''>is</span> <span style=''>if</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trusted</span> <span style=''>in</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>when</span> <span style=''>faced</span> <span style=''>with</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>input</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>hashing</span> <span style=''>namely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>with</span> <span style=''>the</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>hashing</span> <span style=''>(OPH)</span> <span style=''>scheme</span> <span style=''>of</span> <span style=''>Li</span> <span style=''>et</span> <span style=''>al</span> <span style=''>NIPS12</span> <span style=''>and</span> <span style=''>feature</span> <span style=''>hashing</span> <span style=''>(FH)</span> <span style=''>of</span> <span style=''>Weinberger</span> <span style=''>et</span> <span style=''>al</span> <span style=''>ICML09</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Hybrid</span> <span style=''>Domains</span> <br/><br/><span style=''>While</span> <span style=''>all</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>data</span> <span style=''>from</span> <span style=''>personal</span> <span style=''>data</span> <span style=''>over</span> <span style=''>panel</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style=''>data</span> <span style=''>to</span> <span style=''>public</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>commercial</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3650793650793651);'>collected</span> <span style=''>and</span> <span style=''>stored</span> <span style=''>building</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>these</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>becomes</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>Users</span> <span style=''>spend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>time</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3202614379084967);'>parametric</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3881748071979434);'>variables</span> <span style=''>(Gaussian</span> <span style=''>Poisson</span> <span style=''>Logit</span> <span style=''>etc)</span> <span style=''>involved</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>mixed</span> <span style=''>models</span> <span style=''>To</span> <span style=''>make</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>task</span> <span style=''>easier</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.6428571428571428);'>trainable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.5208333333333333);'>architecture</span> <span style=''>for</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>that</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>queries</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>(SPNs)</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>leave</span> <span style='background-color:rgba(255, 0, 0, 0.3988095238095239);'>distributions</span> <span style=''>together</span> <span style=''>with</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.7333333333333334);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>dynamic</span> <span style=''>ensemble</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preprocessing</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imbalance</span> <span style=''>learning</span> <br/><br/><span style=''>Class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imbalance</span> <span style=''>refers</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>which</span> <span style=''>many</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>for</span> <span style=''>certain</span> <span style=''>classes</span> <span style=''>than</span> <span style=''>for</span> <span style=''>others</span> <span style=''>Such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>datasets</span> <span style=''>require</span> <span style=''>special</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>because</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>favor</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>class</span> <span style=''>which</span> <span style=''>has</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>Ensemble</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>have</span> <span style=''>been</span> <span style=''>reported</span> <span style=''>to</span> <span style=''>yield</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>results</span> <span style=''>However</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>ensemble</span> <span style=''>methods</span> <span style=''>applied</span> <span style=''>too</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>static</span> <span style=''>ones</span> <span style=''>Moreover</span> <span style=''>they</span> <span style=''>only</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>problems</span> <span style=''>Hence</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>and</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preprocessing</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>problems</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12714899713467048)
# 	challenging (0.09419770773638969)
# 	representation (0.13073065902578795)
# 	information (0.2431948424068768)
# 	evaluation (0.10744985673352435)
# 	segmentation (0.08022922636103152)
# 	detection (0.12464183381088825)
# 	convolutional (0.13502865329512895)
# 	recognition (0.13753581661891118)
# 	different (0.2815186246418338)
#
# Some Statistics words are:
# 	stochastic (0.1344621513944223)
# 	distribution (0.175796812749004)
# 	variables (0.1344621513944223)
# 	algorithm (0.3999003984063745)
# 	theoretical (0.15139442231075698)
# 	estimation (0.16583665338645417)
# 	statistical (0.16135458167330677)
# 	inference (0.1942231075697211)
# 	dimensional (0.1852589641434263)
# 	regression (0.17878486055776893)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="399119b6-5f7d-4aa4-865e-493a8f030e19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("399119b6-5f7d-4aa4-865e-493a8f030e19")) {                    Plotly.newPlot(                        "399119b6-5f7d-4aa4-865e-493a8f030e19",                        [{"x":["introduced","additional","symmetric","properties","descriptive","information","clustering","complexity","difference","mathematical","difficult","explorations","discriminating","investigated","investigate","understand","challenging","experiments","performance","evaluations","sentences","classifiers","varieties","annotation","languages","combination","identified","evaluation","comparison","techniques","kernelized","represent","percentage","selection","categories","different","predicting","introduces","behaviour","preparation","comparative","presented","methodologies","description","continuous","facilitate","contributions","appearance","evaluated","annotated","unconstrained","extensive","conditions","resolution","variation","assumptions","regarding","experience","laboratory","illumination","collected","positions","challenges","environment","informative","monocular","corresponding","including","addressing","estimation","limitations","realistic","increasing","contribution","posteriors","parameters","approaches","posterior","distributions","furthermore","benchmark","denoising","saturates","variational","independent","independently","contributes","separation","benchmarks","dimensions","applications","independence","truncated","inference","distribution","application","computational","alternating","simultaneously","regularization","minimization","relationship","multitask","experimental","formulated","formulation","efficiently","significantly","comparable","formulations","algorithm","framework","outperform","incorporate","automatically","leveraging","knowledge","reinforced","developed","numerical","annealing","augmented","stochastic","evolutionary","optimization","competitive","respectively","differential","polynomial","engineering","simplified","efficiency","practical","stability","algorithms","evolution","robustness","performed","simulated","submodular","establish","functions","penalized","relaxation","combinatorial","tightness","situation","penalties","regularized","represents","parameter","relaxations","representations","structured","characterizes","introduce","procedure","intuitive","completing","structural","satisfies","constraint","incoherence","advantages","incoherent","uniformly","recovered","proportional","according","completion","currently","probability","important","restrictive","necessary","characterize","interpretability","comparing","procedures","association","portraying","understanding","applicability","interpretable","identifying","databases","constructed","dictionaries","integrate","etymological","principles","continuum","comprehensive","systematic","interested","possibilities","seamlessly","contribute","representation","designing","constructs","guidelines","phenomena","explanations","nonconformity","direction","neighbors","separates","predictions","malicious","estimates","accurately","confident","classifier","inability","translation","desirable","confidence","innovative","prediction","adversarial","detection","structure","recognition","strategies","vulnerability","neighboring","criticized","constitute","converges","motivated","tractable","linearized","generated","restricted","effectiveness","equivalence","approximations","convexity","efficient","impractical","decomposition","discovers","demonstrate","memberships","overlapping","interaction","predictive","international","communities","relations","community","transition","nonlinear","arbitrary","exponential"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	preventive
# 	ultrametric
# 	contextualizing
# 	blackwellized
# 	attaining
# 	tightening
# 	inversions
# 	concordant
# 	subdomains
# 	sparsistent
# 	tibshirani
# 	distributionally
# 	spreading
# 	underdamped
# 	obtainable
# 	emphmulti
# 	staleness
# 	intercept
# 	groupings
# 	resurgence
# Some words which never appear in Statistics papers:
# 	explorations
# 	monocular
# 	reinforced
# 	portraying
# 	etymological
# 	grammaticality
# 	microblog
# 	multiword
# 	avoidance
# 	exercised
# 	surpassing
# 	psychological
# 	validates
# 	disturbances
# 	infrequent
# 	photometric
# 	traversability
# 	triangulation
# 	neuropsychological
# 	countermeasure

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0780595912336864e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
